# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/generative-dog-images/Annotation.zip
# /kaggle/input/generative-dog-images/all-dogs.zip

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch import nn, optim
import torch.nn.functional as F
from torchvision import datasets, transforms
from torchvision.utils import save_image
import os

batch_size = 32

# 64x64 images!
transform = transforms.Compose([transforms.Resize(64),
                                transforms.CenterCrop(64),
                                transforms.ToTensor(),
                                transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

train_data = datasets.ImageFolder('../input/all-dogs/', transform=transform)
train_loader = torch.utils.data.DataLoader(train_data, shuffle=True,
                                           batch_size=batch_size)
                                           
imgs, label = next(iter(train_loader))
imgs = imgs.numpy().transpose(0, 2, 3, 1)

class Generator(nn.Module):
    def __init__(self, nz, nfeats, nchannels):
        super(Generator, self).__init__()

        # input is Z, going into a convolution
        self.conv1 = nn.ConvTranspose2d(nz, nfeats * 8, 4, 1, 0, bias=False)
        self.bn1 = nn.BatchNorm2d(nfeats * 8)
        # state size. (nfeats*8) x 4 x 4
        
        self.conv2 = nn.ConvTranspose2d(nfeats * 8, nfeats * 8, 4, 2, 1, bias=False)
        self.bn2 = nn.BatchNorm2d(nfeats * 8)
        # state size. (nfeats*8) x 8 x 8
        
        self.conv3 = nn.ConvTranspose2d(nfeats * 8, nfeats * 4, 4, 2, 1, bias=False)
        self.bn3 = nn.BatchNorm2d(nfeats * 4)
        # state size. (nfeats*4) x 16 x 16
        
        self.conv4 = nn.ConvTranspose2d(nfeats * 4, nfeats * 2, 4, 2, 1, bias=False)
        self.bn4 = nn.BatchNorm2d(nfeats * 2)
        # state size. (nfeats * 2) x 32 x 32
        
        self.conv5 = nn.ConvTranspose2d(nfeats * 2, nfeats, 4, 2, 1, bias=False)
        self.bn5 = nn.BatchNorm2d(nfeats)
        # state size. (nfeats) x 64 x 64
        
        self.conv6 = nn.ConvTranspose2d(nfeats, nchannels, 3, 1, 1, bias=False)
        # state size. (nchannels) x 64 x 64

    def forward(self, x):
        x = F.leaky_relu(self.bn1(self.conv1(x)))
        x = F.leaky_relu(self.bn2(self.conv2(x)))
        x = F.leaky_relu(self.bn3(self.conv3(x)))
        x = F.leaky_relu(self.bn4(self.conv4(x)))
        x = F.leaky_relu(self.bn5(self.conv5(x)))
        #x = torch.relu(self.conv6(x))
        x = torch.tanh(self.conv6(x))
        
        return x



class Discriminator(nn.Module):
    def __init__(self, nchannels, nfeats):
        super(Discriminator, self).__init__()

        # input is (nchannels) x 64 x 64
        self.conv1 = nn.Conv2d(nchannels, nfeats, 4, 2, 1, bias=False)
        # state size. (nfeats) x 32 x 32
        
        self.conv2 = nn.Conv2d(nfeats, nfeats * 2, 4, 2, 1, bias=False)
        self.bn2 = nn.BatchNorm2d(nfeats * 2)
        # state size. (nfeats*2) x 16 x 16
        
        self.conv3 = nn.Conv2d(nfeats * 2, nfeats * 4, 4, 2, 1, bias=False)
        self.bn3 = nn.BatchNorm2d(nfeats * 4)
        # state size. (nfeats*4) x 8 x 8
       
        self.conv4 = nn.Conv2d(nfeats * 4, nfeats * 8, 4, 2, 1, bias=False)
        self.bn4 = nn.BatchNorm2d(nfeats * 8)
        # state size. (nfeats*8) x 4 x 4
        
        self.conv5 = nn.Conv2d(nfeats * 8, 1, 4, 1, 0, bias=False)
        # state size. 1 x 1 x 1
        
    def forward(self, x):
        x = F.leaky_relu(self.conv1(x), 0.2)
        x = F.leaky_relu(self.bn2(self.conv2(x)), 0.2)
        x = F.leaky_relu(self.bn3(self.conv3(x)), 0.2)
        x = F.leaky_relu(self.bn4(self.conv4(x)), 0.2)
        x = torch.sigmoid(self.conv5(x))
        
        return x.view(-1, 1)


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

lr = 0.0003
beta1 = 0.5

netG = Generator(100, 32, 3).to(device)
netD = Discriminator(3, 48).to(device)

criterion = nn.BCELoss()

optimizerD = optim.Adam(netD.parameters(), lr=lr, betas=(beta1, 0.999))
optimizerG = optim.Adam(netG.parameters(), lr=lr, betas=(beta1, 0.999))

nz = 100
fixed_noise = torch.randn(25, nz, 1, 1, device=device)

real_label = 0.9
fake_label = 0
batch_size = train_loader.batch_size



### training here

epochs = 4 #10 #5 #2

step = 0
for epoch in range(epochs):
    for ii, (real_images, train_labels) in enumerate(train_loader):
        ############################
        # (1) Update D network: maximize log(D(x)) + log(1 - D(G(z)))
        ###########################
        # train with real
        netD.zero_grad()
        real_images = real_images.to(device)
        batch_size = real_images.size(0)
        labels = torch.full((batch_size, 1), real_label, device=device)

        output = netD(real_images)
        errD_real = criterion(output, labels)
        errD_real.backward()
        D_x = output.mean().item()

        # train with fake
        noise = torch.randn(batch_size, nz, 1, 1, device=device)
        fake = netG(noise)
        labels.fill_(fake_label)
        output = netD(fake.detach())
        errD_fake = criterion(output, labels)
        errD_fake.backward()
        D_G_z1 = output.mean().item()
        errD = errD_real + errD_fake
        optimizerD.step()

        ############################
        # (2) Update G network: maximize log(D(G(z)))
        ###########################
        netG.zero_grad()
        labels.fill_(real_label)  # fake labels are real for generator cost
        output = netD(fake)
        errG = criterion(output, labels)
        errG.backward()
        D_G_z2 = output.mean().item()
        optimizerG.step()
        
        if step % 500 == 0:
            print('[%d/%d][%d/%d] Loss_D: %.4f Loss_G: %.4f D(x): %.4f D(G(z)): %.4f / %.4f'
                  % (epoch + 1, epochs, ii, len(train_loader),
                     errD.item(), errG.item(), D_x, D_G_z1, D_G_z2))
            
            valid_image = netG(fixed_noise)
        step += 1
        
        
# torch.save(netG.state_dict(), 'generator.pth')
# torch.save(netD.state_dict(), 'discriminator.pth')


if not os.path.exists('../output_images'):
    os.mkdir('../output_images')
im_batch_size = 50
n_images=10000
for i_batch in range(0, n_images, im_batch_size):
    gen_z = torch.randn(im_batch_size, 100, 1, 1, device=device)
    gen_images = netG(gen_z)
    images = gen_images.to("cpu").clone().detach()
    images = images.numpy().transpose(0, 2, 3, 1)
    for i_image in range(gen_images.size(0)):
        save_image(gen_images[i_image, :, :, :], os.path.join('../output_images', f'image_{i_batch+i_image:05d}.png'))


import shutil
shutil.make_archive('images', 'zip', '../output_images')

# [1/4][0/644] Loss_D: 1.3841 Loss_G: 1.9730 D(x): 0.5686 D(G(z)): 0.5422 / 0.1148
# [1/4][500/644] Loss_D: 1.1209 Loss_G: 5.9773 D(x): 0.8809 D(G(z)): 0.5089 / 0.0016
# [2/4][356/644] Loss_D: 0.9004 Loss_G: 2.3730 D(x): 0.7132 D(G(z)): 0.3404 / 0.0811
# [3/4][212/644] Loss_D: 1.2560 Loss_G: 1.1276 D(x): 0.3713 D(G(z)): 0.2200 / 0.3152
# [4/4][68/644] Loss_D: 0.9173 Loss_G: 2.2228 D(x): 0.7263 D(G(z)): 0.3503 / 0.0971
# [4/4][568/644] Loss_D: 0.9449 Loss_G: 1.7831 D(x): 0.5526 D(G(z)): 0.1851 / 0.1637

'/kaggle/working/images.zip'
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 18
#      12 # 64x64 images!
#      13 transform = transforms.Compose([transforms.Resize(64),
#      14                                 transforms.CenterCrop(64),
#      15                                 transforms.ToTensor(),
#      16                                 transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
# ---> 18 train_data = datasets.ImageFolder('../input/all-dogs/', transform=transform)
#      19 train_loader = torch.utils.data.DataLoader(train_data, shuffle=True,
#      20                                            batch_size=batch_size)
#      22 imgs, label = next(iter(train_loader))
#
# File /opt/conda/lib/python3.10/site-packages/torchvision/datasets/folder.py:309, in ImageFolder.__init__(self, root, transform, target_transform, loader, is_valid_file)
#     301 def __init__(
#     302     self,
#     303     root: str,
#    (...)
#     307     is_valid_file: Optional[Callable[[str], bool]] = None,
#     308 ):
# --> 309     super().__init__(
#     310         root,
#     311         loader,
#     312         IMG_EXTENSIONS if is_valid_file is None else None,
#     313         transform=transform,
#     314         target_transform=target_transform,
#     315         is_valid_file=is_valid_file,
#     316     )
#     317     self.imgs = self.samples
#
# File /opt/conda/lib/python3.10/site-packages/torchvision/datasets/folder.py:144, in DatasetFolder.__init__(self, root, loader, extensions, transform, target_transform, is_valid_file)
#     134 def __init__(
#     135     self,
#     136     root: str,
#    (...)
#     141     is_valid_file: Optional[Callable[[str], bool]] = None,
#     142 ) -> None:
#     143     super().__init__(root, transform=transform, target_transform=target_transform)
# --> 144     classes, class_to_idx = self.find_classes(self.root)
#     145     samples = self.make_dataset(self.root, class_to_idx, extensions, is_valid_file)
#     147     self.loader = loader
#
# File /opt/conda/lib/python3.10/site-packages/torchvision/datasets/folder.py:218, in DatasetFolder.find_classes(self, directory)
#     191 def find_classes(self, directory: str) -> Tuple[List[str], Dict[str, int]]:
#     192     """Find the class folders in a dataset structured as follows::
#     193
#     194         directory/
#    (...)
#     216         (Tuple[List[str], Dict[str, int]]): List of all classes and dictionary mapping each class to an index.
#     217     """
# --> 218     return find_classes(directory)
#
# File /opt/conda/lib/python3.10/site-packages/torchvision/datasets/folder.py:40, in find_classes(directory)
#      35 def find_classes(directory: str) -> Tuple[List[str], Dict[str, int]]:
#      36     """Finds the class folders in a dataset.
#      37
#      38     See :class:`DatasetFolder` for details.
#      39     """
# ---> 40     classes = sorted(entry.name for entry in os.scandir(directory) if entry.is_dir())
#      41     if not classes:
#      42         raise FileNotFoundError(f"Couldn't find any class folder in {directory}.")
#
# FileNotFoundError: [Errno 2] No such file or directory: '../input/all-dogs/'

# %%
import zipfile
with zipfile.ZipFile("../input/generative-dog-images/all-dogs.zip","r") as zip_ref:
    zip_ref.extractall("/kaggle/temp/")

# %%
import zipfile
with zipfile.ZipFile("../input/generative-dog-images/Annotation.zip","r") as zip_ref:
    zip_ref.extractall("/kaggle/temp/")

# %%
ComputeLB = False
DogsOnly = False
import numpy as np, pandas as pd, os
import xml.etree.ElementTree as ET 
import matplotlib.pyplot as plt, zipfile 
from PIL import Image

# %%
SEED = 4250
np.random.seed(SEED)
random_dim = 128

ROOT = '/kaggle/temp/'
#if not ComputeLB: ROOT = '/kaggle/working/'
breeds = os.listdir(ROOT + 'Annotation') 
IMAGES = os.listdir(ROOT + 'all-dogs')

# %%
# !unzip '../input/generative-dog-images/Annotation.zip'
# !unzip '../input/generative-dog-images/all-dogs.zip'
# Out:
# Archive:  ../input/generative-dog-images/Annotation.zip
#    creating: Annotation/
#    creating: Annotation/n02097658-silky_terrier/
#   inflating: Annotation/n02097658-silky_terrier/n02097658_98
#    creating: __MACOSX/
#    creating: __MACOSX/Annotation/
#    creating: __MACOSX/Annotation/n02097658-silky_terrier/
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_98
#   inflating: Annotation/n02097658-silky_terrier/n02097658_2535
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_2535
#   inflating: Annotation/n02097658-silky_terrier/n02097658_271
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_271
#   inflating: Annotation/n02097658-silky_terrier/n02097658_427
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_427
#   inflating: Annotation/n02097658-silky_terrier/n02097658_4890
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_4890
#   inflating: Annotation/n02097658-silky_terrier/n02097658_5728
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_5728
#   inflating: Annotation/n02097658-silky_terrier/n02097658_646
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_646
#   inflating: Annotation/n02097658-silky_terrier/n02097658_2330
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_2330
#   inflating: Annotation/n02097658-silky_terrier/n02097658_4201
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_4201
#   inflating: Annotation/n02097658-silky_terrier/n02097658_6300
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_6300
#   inflating: Annotation/n02097658-silky_terrier/n02097658_641
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_641
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1917
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1917
#   inflating: Annotation/n02097658-silky_terrier/n02097658_10654
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_10654
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1789
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1789
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1326
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1326
#   inflating: Annotation/n02097658-silky_terrier/n02097658_8409
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_8409
#   inflating: Annotation/n02097658-silky_terrier/n02097658_214
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_214
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1910
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1910
#   inflating: Annotation/n02097658-silky_terrier/n02097658_4402
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_4402
#   inflating: Annotation/n02097658-silky_terrier/n02097658_7425
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_7425
#   inflating: Annotation/n02097658-silky_terrier/n02097658_277
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_277
#   inflating: Annotation/n02097658-silky_terrier/n02097658_10854
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_10854
#   inflating: Annotation/n02097658-silky_terrier/n02097658_7619
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_7619
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1112
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1112
#   inflating: Annotation/n02097658-silky_terrier/n02097658_8053
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_8053
#   inflating: Annotation/n02097658-silky_terrier/n02097658_9723
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_9723
#   inflating: Annotation/n02097658-silky_terrier/n02097658_3484
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_3484
#   inflating: Annotation/n02097658-silky_terrier/n02097658_4231
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_4231
#   inflating: Annotation/n02097658-silky_terrier/n02097658_5548
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_5548
#   inflating: Annotation/n02097658-silky_terrier/n02097658_9978
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_9978
#   inflating: Annotation/n02097658-silky_terrier/n02097658_3396
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_3396
#   inflating: Annotation/n02097658-silky_terrier/n02097658_6289
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_6289
#   inflating: Annotation/n02097658-silky_terrier/n02097658_6672
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_6672
#   inflating: Annotation/n02097658-silky_terrier/n02097658_2022
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_2022
#   inflating: Annotation/n02097658-silky_terrier/n02097658_366
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_366
#   inflating: Annotation/n02097658-silky_terrier/n02097658_2041
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_2041
#   inflating: Annotation/n02097658-silky_terrier/n02097658_950
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_950
#   inflating: Annotation/n02097658-silky_terrier/n02097658_2048
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_2048
#   inflating: Annotation/n02097658-silky_terrier/n02097658_4728
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_4728
#   inflating: Annotation/n02097658-silky_terrier/n02097658_8323
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_8323
#   inflating: Annotation/n02097658-silky_terrier/n02097658_9407
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_9407
#   inflating: Annotation/n02097658-silky_terrier/n02097658_552
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_552
#   inflating: Annotation/n02097658-silky_terrier/n02097658_6014
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_6014
#   inflating: Annotation/n02097658-silky_terrier/n02097658_758
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_758
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1469
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1469
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1690
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1690
#   inflating: Annotation/n02097658-silky_terrier/n02097658_2012
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_2012
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1473
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1473
#   inflating: Annotation/n02097658-silky_terrier/n02097658_11020
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_11020
#   inflating: Annotation/n02097658-silky_terrier/n02097658_319
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_319
#   inflating: Annotation/n02097658-silky_terrier/n02097658_5223
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_5223
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1086
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1086
#   inflating: Annotation/n02097658-silky_terrier/n02097658_727
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_727
#   inflating: Annotation/n02097658-silky_terrier/n02097658_171
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_171
#   inflating: Annotation/n02097658-silky_terrier/n02097658_6605
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_6605
#   inflating: Annotation/n02097658-silky_terrier/n02097658_6202
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_6202
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1018
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1018
#   inflating: Annotation/n02097658-silky_terrier/n02097658_329
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_329
#   inflating: Annotation/n02097658-silky_terrier/n02097658_7785
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_7785
#   inflating: Annotation/n02097658-silky_terrier/n02097658_3117
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_3117
#   inflating: Annotation/n02097658-silky_terrier/n02097658_7970
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_7970
#   inflating: Annotation/n02097658-silky_terrier/n02097658_980
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_980
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1270
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1270
#   inflating: Annotation/n02097658-silky_terrier/n02097658_3947
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_3947
#   inflating: Annotation/n02097658-silky_terrier/n02097658_6867
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_6867
#   inflating: Annotation/n02097658-silky_terrier/n02097658_4992
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_4992
#   inflating: Annotation/n02097658-silky_terrier/n02097658_2054
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_2054
#   inflating: Annotation/n02097658-silky_terrier/n02097658_141
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_141
#   inflating: Annotation/n02097658-silky_terrier/n02097658_5420
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_5420
#   inflating: Annotation/n02097658-silky_terrier/n02097658_942
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_942
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1106
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1106
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1137
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1137
#   inflating: Annotation/n02097658-silky_terrier/n02097658_3693
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_3693
#   inflating: Annotation/n02097658-silky_terrier/n02097658_2117
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_2117
#   inflating: Annotation/n02097658-silky_terrier/n02097658_237
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_237
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1356
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1356
#   inflating: Annotation/n02097658-silky_terrier/n02097658_2143
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_2143
#   inflating: Annotation/n02097658-silky_terrier/n02097658_4081
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_4081
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1163
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1163
#   inflating: Annotation/n02097658-silky_terrier/n02097658_7893
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_7893
#   inflating: Annotation/n02097658-silky_terrier/n02097658_46
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_46
#   inflating: Annotation/n02097658-silky_terrier/n02097658_9300
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_9300
#   inflating: Annotation/n02097658-silky_terrier/n02097658_4420
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_4420
#   inflating: Annotation/n02097658-silky_terrier/n02097658_6784
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_6784
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1793
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1793
#   inflating: Annotation/n02097658-silky_terrier/n02097658_8619
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_8619
#   inflating: Annotation/n02097658-silky_terrier/n02097658_10020
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_10020
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1100
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1100
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1198
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1198
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1154
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1154
#   inflating: Annotation/n02097658-silky_terrier/n02097658_2173
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_2173
#   inflating: Annotation/n02097658-silky_terrier/n02097658_9330
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_9330
#   inflating: Annotation/n02097658-silky_terrier/n02097658_3407
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_3407
#   inflating: Annotation/n02097658-silky_terrier/n02097658_642
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_642
#   inflating: Annotation/n02097658-silky_terrier/n02097658_7474
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_7474
#   inflating: Annotation/n02097658-silky_terrier/n02097658_7445
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_7445
#   inflating: Annotation/n02097658-silky_terrier/n02097658_9987
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_9987
#   inflating: Annotation/n02097658-silky_terrier/n02097658_2766
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_2766
#   inflating: Annotation/n02097658-silky_terrier/n02097658_11118
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_11118
#   inflating: Annotation/n02097658-silky_terrier/n02097658_4869
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_4869
#   inflating: Annotation/n02097658-silky_terrier/n02097658_8653
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_8653
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1516
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1516
#   inflating: Annotation/n02097658-silky_terrier/n02097658_6357
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_6357
#   inflating: Annotation/n02097658-silky_terrier/n02097658_611
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_611
#   inflating: Annotation/n02097658-silky_terrier/n02097658_9327
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_9327
#   inflating: Annotation/n02097658-silky_terrier/n02097658_9727
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_9727
#   inflating: Annotation/n02097658-silky_terrier/n02097658_11313
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_11313
#   inflating: Annotation/n02097658-silky_terrier/n02097658_8095
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_8095
#   inflating: Annotation/n02097658-silky_terrier/n02097658_816
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_816
#   inflating: Annotation/n02097658-silky_terrier/n02097658_6351
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_6351
#   inflating: Annotation/n02097658-silky_terrier/n02097658_8690
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_8690
#   inflating: Annotation/n02097658-silky_terrier/n02097658_422
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_422
#   inflating: Annotation/n02097658-silky_terrier/n02097658_414
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_414
#   inflating: Annotation/n02097658-silky_terrier/n02097658_595
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_595
#   inflating: Annotation/n02097658-silky_terrier/n02097658_11235
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_11235
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1039
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1039
#   inflating: Annotation/n02097658-silky_terrier/n02097658_6678
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_6678
#   inflating: Annotation/n02097658-silky_terrier/n02097658_2882
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_2882
#   inflating: Annotation/n02097658-silky_terrier/n02097658_955
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_955
#   inflating: Annotation/n02097658-silky_terrier/n02097658_2271
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_2271
#   inflating: Annotation/n02097658-silky_terrier/n02097658_8780
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_8780
#   inflating: Annotation/n02097658-silky_terrier/n02097658_4778
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_4778
#   inflating: Annotation/n02097658-silky_terrier/n02097658_2824
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_2824
#   inflating: Annotation/n02097658-silky_terrier/n02097658_6017
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_6017
#   inflating: Annotation/n02097658-silky_terrier/n02097658_2224
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_2224
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1693
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1693
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1065
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1065
#   inflating: Annotation/n02097658-silky_terrier/n02097658_953
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_953
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1868
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1868
#   inflating: Annotation/n02097658-silky_terrier/n02097658_2087
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_2087
#   inflating: Annotation/n02097658-silky_terrier/n02097658_7162
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_7162
#   inflating: Annotation/n02097658-silky_terrier/n02097658_6044
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_6044
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1098
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1098
#   inflating: Annotation/n02097658-silky_terrier/n02097658_2069
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_2069
#   inflating: Annotation/n02097658-silky_terrier/n02097658_5273
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_5273
#   inflating: Annotation/n02097658-silky_terrier/n02097658_349
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_349
#   inflating: Annotation/n02097658-silky_terrier/n02097658_3345
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_3345
#   inflating: Annotation/n02097658-silky_terrier/n02097658_2051
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_2051
#   inflating: Annotation/n02097658-silky_terrier/n02097658_188
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_188
#   inflating: Annotation/n02097658-silky_terrier/n02097658_10997
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_10997
#   inflating: Annotation/n02097658-silky_terrier/n02097658_11242
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_11242
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1616
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1616
#   inflating: Annotation/n02097658-silky_terrier/n02097658_4952
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_4952
#   inflating: Annotation/n02097658-silky_terrier/n02097658_4363
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_4363
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1013
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1013
#   inflating: Annotation/n02097658-silky_terrier/n02097658_3571
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_3571
#   inflating: Annotation/n02097658-silky_terrier/n02097658_10559
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_10559
#   inflating: Annotation/n02097658-silky_terrier/n02097658_2665
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_2665
#   inflating: Annotation/n02097658-silky_terrier/n02097658_5643
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_5643
#   inflating: Annotation/n02097658-silky_terrier/n02097658_983
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_983
#   inflating: Annotation/n02097658-silky_terrier/n02097658_3140
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_3140
#   inflating: Annotation/n02097658-silky_terrier/n02097658_8767
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_8767
#   inflating: Annotation/n02097658-silky_terrier/n02097658_9017
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_9017
#   inflating: Annotation/n02097658-silky_terrier/n02097658_9222
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_9222
#   inflating: Annotation/n02097658-silky_terrier/n02097658_129
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_129
#   inflating: Annotation/n02097658-silky_terrier/n02097658_9043
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_9043
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1227
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1227
#   inflating: Annotation/n02097658-silky_terrier/n02097658_10567
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_10567
#   inflating: Annotation/n02097658-silky_terrier/n02097658_2035
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_2035
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1997
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1997
#   inflating: Annotation/n02097658-silky_terrier/n02097658_2523
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_2523
#   inflating: Annotation/n02097658-silky_terrier/n02097658_6726
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_6726
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1503
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1503
#   inflating: Annotation/n02097658-silky_terrier/n02097658_3639
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_3639
#   inflating: Annotation/n02097658-silky_terrier/n02097658_2182
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_2182
#   inflating: Annotation/n02097658-silky_terrier/n02097658_9136
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_9136
#   inflating: Annotation/n02097658-silky_terrier/n02097658_2919
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_2919
#   inflating: Annotation/n02097658-silky_terrier/n02097658_2114
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_2114
#   inflating: Annotation/n02097658-silky_terrier/n02097658_3207
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_3207
#   inflating: Annotation/n02097658-silky_terrier/n02097658_633
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_633
#   inflating: Annotation/n02097658-silky_terrier/n02097658_10289
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_10289
#   inflating: Annotation/n02097658-silky_terrier/n02097658_292
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_292
#   inflating: Annotation/n02097658-silky_terrier/n02097658_11363
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_11363
#   inflating: Annotation/n02097658-silky_terrier/n02097658_857
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_857
#   inflating: Annotation/n02097658-silky_terrier/n02097658_5535
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_5535
#   inflating: Annotation/n02097658-silky_terrier/n02097658_8018
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_8018
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1307
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1307
#   inflating: Annotation/n02097658-silky_terrier/n02097658_6546
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_6546
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1797
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1797
#   inflating: Annotation/n02097658-silky_terrier/n02097658_26
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_26
#   inflating: Annotation/n02097658-silky_terrier/n02097658_6
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_6
#   inflating: Annotation/n02097658-silky_terrier/n02097658_1567
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_1567
#   inflating: Annotation/n02097658-silky_terrier/n02097658_2329
#   inflating: __MACOSX/Annotation/n02097658-silky_terrier/._n02097658_2329
#   inflating: __MACOSX/Annotation/._n02097658-silky_terrier
#    creating: Annotation/n02092002-Scottish_deerhound/
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_5377
#    creating: __MACOSX/Annotation/n02092002-Scottish_deerhound/
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_5377
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_15215
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_15215
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_6508
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_6508
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_6702
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_6702
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_4258
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_4258
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_7825
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_7825
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_14369
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_14369
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_4657
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_4657
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_11088
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_11088
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_5915
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_5915
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_700
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_700
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_7473
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_7473
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_3271
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_3271
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_15010
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_15010
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_6735
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_6735
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_5746
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_5746
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_6302
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_6302
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_2590
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_2590
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_11428
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_11428
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_11087
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_11087
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_6625
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_6625
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_817
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_817
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_5437
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_5437
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_1438
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_1438
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_3968
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_3968
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_228
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_228
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_14825
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_14825
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_15198
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_15198
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_9862
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_9862
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_4545
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_4545
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_15165
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_15165
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_7539
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_7539
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_7165
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_7165
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_11131
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_11131
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_7537
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_7537
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_12544
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_12544
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_1439
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_1439
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_49
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_49
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_4517
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_4517
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_3500
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_3500
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_4118
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_4118
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_5668
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_5668
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_1693
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_1693
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_12977
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_12977
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_7751
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_7751
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_5462
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_5462
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_5202
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_5202
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_9863
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_9863
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_5008
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_5008
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_15342
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_15342
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_293
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_293
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_4134
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_4134
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_6003
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_6003
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_1828
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_1828
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_4337
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_4337
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_10699
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_10699
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_498
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_498
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_15112
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_15112
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_12595
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_12595
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_4169
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_4169
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_692
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_692
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_9224
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_9224
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_5617
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_5617
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_6698
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_6698
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_10060
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_10060
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_4338
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_4338
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_7743
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_7743
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_5226
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_5226
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_3343
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_3343
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_1242
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_1242
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_6609
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_6609
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_3988
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_3988
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_1339
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_1339
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_1937
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_1937
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_3494
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_3494
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_7206
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_7206
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_7696
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_7696
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_3460
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_3460
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_5936
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_5936
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_6585
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_6585
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_1592
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_1592
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_13159
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_13159
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_7890
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_7890
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_12828
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_12828
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_10911
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_10911
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_2981
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_2981
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_6380
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_6380
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_14917
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_14917
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_11459
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_11459
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_2372
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_2372
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_5557
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_5557
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_6114
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_6114
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_4218
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_4218
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_4220
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_4220
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_2311
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_2311
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_983
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_983
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_12414
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_12414
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_6780
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_6780
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_1551
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_1551
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_348
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_348
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_1962
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_1962
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_1730
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_1730
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_120
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_120
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_5504
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_5504
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_6729
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_6729
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_14540
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_14540
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_2184
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_2184
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_6907
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_6907
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_1583
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_1583
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_3485
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_3485
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_4230
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_4230
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_13380
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_13380
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_5916
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_5916
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_1727
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_1727
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_14102
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_14102
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_759
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_759
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_6534
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_6534
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_305
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_305
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_1147
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_1147
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_6953
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_6953
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_9785
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_9785
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_2558
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_2558
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_13372
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_13372
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_6339
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_6339
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_198
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_198
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_11245
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_11245
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_4296
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_4296
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_4898
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_4898
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_109
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_109
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_6955
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_6955
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_6963
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_6963
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_14567
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_14567
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_1170
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_1170
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_6503
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_6503
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_885
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_885
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_7791
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_7791
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_5664
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_5664
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_9895
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_9895
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_2217
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_2217
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_1698
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_1698
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_4745
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_4745
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_6827
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_6827
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_15354
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_15354
#   inflating: Annotation/n02092002-Scottish_deerhound/n02092002_11390
#   inflating: __MACOSX/Annotation/n02092002-Scottish_deerhound/._n02092002_11390
# ...
#   inflating: all-dogs/n02105162_9927.jpg
#   inflating: all-dogs/n02098413_1693.jpg
#   inflating: all-dogs/n02108915_2835.jpg
#   inflating: all-dogs/n02092002_14567.jpg
#   inflating: all-dogs/n02112137_14004.jpg
#   inflating: all-dogs/n02085782_1528.jpg
#   inflating: all-dogs/n02112018_10158.jpg
#   inflating: all-dogs/n02111889_6950.jpg
#   inflating: all-dogs/n02107683_2036.jpg
#   inflating: all-dogs/n02112137_8410.jpg
#   inflating: all-dogs/n02093859_3267.jpg
#   inflating: all-dogs/n02096051_3750.jpg
#   inflating: all-dogs/n02099849_4692.jpg
#   inflating: all-dogs/n02115641_7013.jpg
#   inflating: all-dogs/n02108551_1689.jpg
#   inflating: all-dogs/n02085936_7364.jpg
#   inflating: all-dogs/n02097130_5907.jpg
#   inflating: all-dogs/n02092339_2695.jpg
#   inflating: all-dogs/n02112018_5700.jpg
#   inflating: all-dogs/n02107574_169.jpg
#   inflating: all-dogs/n02088466_6963.jpg
#   inflating: all-dogs/n02093256_11732.jpg
#   inflating: all-dogs/n02085936_797.jpg
#   inflating: all-dogs/n02110063_4302.jpg
#   inflating: all-dogs/n02110185_7594.jpg
#   inflating: all-dogs/n02097658_3407.jpg
#   inflating: all-dogs/n02102480_5792.jpg
#   inflating: all-dogs/n02105251_7977.jpg
#   inflating: all-dogs/n02106550_12073.jpg
#   inflating: all-dogs/n02111889_4809.jpg
#   inflating: all-dogs/n02113186_12419.jpg
#   inflating: all-dogs/n02088364_14613.jpg
#   inflating: all-dogs/n02095570_6190.jpg
#   inflating: all-dogs/n02107574_627.jpg
#   inflating: all-dogs/n02095314_1835.jpg
#   inflating: all-dogs/n02098286_2257.jpg
#   inflating: all-dogs/n02112706_1755.jpg
#   inflating: all-dogs/n02089867_145.jpg
#   inflating: all-dogs/n02106550_5184.jpg
#   inflating: all-dogs/n02094258_990.jpg
#   inflating: all-dogs/n02105056_7435.jpg
#   inflating: all-dogs/n02094114_3545.jpg
#   inflating: all-dogs/n02107908_599.jpg
#   inflating: all-dogs/n02105056_1050.jpg
#   inflating: all-dogs/n02086079_8229.jpg
#   inflating: all-dogs/n02101006_22.jpg
#   inflating: all-dogs/n02088094_11584.jpg
#   inflating: all-dogs/n02096051_2314.jpg
#   inflating: all-dogs/n02110185_10597.jpg
#   inflating: all-dogs/n02100236_2854.jpg
#   inflating: all-dogs/n02097209_4508.jpg
#   inflating: all-dogs/n02110185_12380.jpg
#   inflating: all-dogs/n02107908_8207.jpg
#   inflating: all-dogs/n02116738_9798.jpg
#   inflating: all-dogs/n02105056_5550.jpg
#   inflating: all-dogs/n02099849_463.jpg
#   inflating: all-dogs/n02093859_82.jpg
#   inflating: all-dogs/n02098286_4154.jpg
#   inflating: all-dogs/n02095889_293.jpg
#   inflating: all-dogs/n02111500_3095.jpg
#   inflating: all-dogs/n02097130_1585.jpg
#   inflating: all-dogs/n02094114_2129.jpg
#   inflating: all-dogs/n02105505_4398.jpg
#   inflating: all-dogs/n02090721_6715.jpg
#   inflating: all-dogs/n02108422_2046.jpg
#   inflating: all-dogs/n02108089_9724.jpg
#   inflating: all-dogs/n02108000_1324.jpg
#   inflating: all-dogs/n02091244_4986.jpg
#   inflating: all-dogs/n02096294_8157.jpg
#   inflating: all-dogs/n02105251_7750.jpg
#   inflating: all-dogs/n02111500_7218.jpg
#   inflating: all-dogs/n02099267_5415.jpg
#   inflating: all-dogs/n02097130_5708.jpg
#   inflating: all-dogs/n02089867_2319.jpg
#   inflating: all-dogs/n02085782_754.jpg
#   inflating: all-dogs/n02109047_30923.jpg
#   inflating: all-dogs/n02090622_8303.jpg
#   inflating: all-dogs/n02093256_1384.jpg
#   inflating: all-dogs/n02107142_17564.jpg
#   inflating: all-dogs/n02096177_1870.jpg
#   inflating: all-dogs/n02091134_14246.jpg
#   inflating: all-dogs/n02105412_4669.jpg
#   inflating: all-dogs/n02085620_8636.jpg
#   inflating: all-dogs/n02106382_3425.jpg
#   inflating: all-dogs/n02097474_8688.jpg
#   inflating: all-dogs/n02106030_15074.jpg
#   inflating: all-dogs/n02110063_14434.jpg
#   inflating: all-dogs/n02085620_3763.jpg
#   inflating: all-dogs/n02085620_5312.jpg
#   inflating: all-dogs/n02107683_6293.jpg
#   inflating: all-dogs/n02093991_1202.jpg
#   inflating: all-dogs/n02091134_16337.jpg
#   inflating: all-dogs/n02109525_3667.jpg
#   inflating: all-dogs/n02113978_2695.jpg
#   inflating: all-dogs/n02090721_1085.jpg
#   inflating: all-dogs/n02108422_2052.jpg
#   inflating: all-dogs/n02091831_566.jpg
#   inflating: all-dogs/n02097474_85.jpg
#   inflating: all-dogs/n02092339_6430.jpg
#   inflating: all-dogs/n02102040_1674.jpg
#   inflating: all-dogs/n02109961_1253.jpg
#   inflating: all-dogs/n02110063_7810.jpg
#   inflating: all-dogs/n02097209_2810.jpg
#   inflating: all-dogs/n02094433_2678.jpg
#   inflating: all-dogs/n02100583_543.jpg
#   inflating: all-dogs/n02108000_2611.jpg
#   inflating: all-dogs/n02089867_2325.jpg
#   inflating: all-dogs/n02101556_8191.jpg
#   inflating: all-dogs/n02099267_40.jpg
#   inflating: all-dogs/n02104029_1709.jpg
#   inflating: all-dogs/n02110185_11138.jpg
#   inflating: all-dogs/n02109961_5035.jpg
#   inflating: all-dogs/n02096294_1629.jpg
#   inflating: all-dogs/n02095314_3039.jpg
#   inflating: all-dogs/n02088364_5090.jpg
#   inflating: all-dogs/n02108551_1104.jpg
#   inflating: all-dogs/n02093256_13858.jpg
#   inflating: all-dogs/n02092339_3212.jpg
#   inflating: all-dogs/n02086646_637.jpg
#   inflating: all-dogs/n02105251_6300.jpg
#   inflating: all-dogs/n02108000_2163.jpg
#   inflating: all-dogs/n02102040_702.jpg
#   inflating: all-dogs/n02090721_1907.jpg
#   inflating: all-dogs/n02099429_248.jpg
#   inflating: all-dogs/n02096177_737.jpg
#   inflating: all-dogs/n02115641_5823.jpg
#   inflating: all-dogs/n02091831_2245.jpg
#   inflating: all-dogs/n02095570_3981.jpg
#   inflating: all-dogs/n02094433_9739.jpg
#   inflating: all-dogs/n02091032_8265.jpg
#   inflating: all-dogs/n02111129_4958.jpg
#   inflating: all-dogs/n02108089_3547.jpg
#   inflating: all-dogs/n02090379_4875.jpg
#   inflating: all-dogs/n02106166_2837.jpg
#   inflating: all-dogs/n02096585_7314.jpg
#   inflating: all-dogs/n02092002_14771.jpg
#   inflating: all-dogs/n02105641_2018.jpg
#   inflating: all-dogs/n02096437_2055.jpg
#   inflating: all-dogs/n02113799_6740.jpg
#   inflating: all-dogs/n02096585_904.jpg
#   inflating: all-dogs/n02096177_4505.jpg
#   inflating: all-dogs/n02108551_7788.jpg
#   inflating: all-dogs/n02109525_751.jpg
#   inflating: all-dogs/n02089973_2308.jpg
#   inflating: all-dogs/n02097047_2426.jpg
#   inflating: all-dogs/n02088364_2502.jpg
#   inflating: all-dogs/n02089078_1668.jpg
#   inflating: all-dogs/n02097658_3639.jpg
#   inflating: all-dogs/n02106662_24110.jpg
#   inflating: all-dogs/n02106382_748.jpg
#   inflating: all-dogs/n02095314_2864.jpg
#   inflating: all-dogs/n02086910_9056.jpg
#   inflating: all-dogs/n02105505_3805.jpg
#   inflating: all-dogs/n02091467_2122.jpg
#   inflating: all-dogs/n02108915_3083.jpg
#   inflating: all-dogs/n02087046_7149.jpg
#   inflating: all-dogs/n02090622_6851.jpg
#   inflating: all-dogs/n02115641_1674.jpg
#   inflating: all-dogs/n02086240_12480.jpg
#   inflating: all-dogs/n02085936_7172.jpg
#   inflating: all-dogs/n02085782_1058.jpg
#   inflating: all-dogs/n02085936_6278.jpg
#   inflating: all-dogs/n02110958_5069.jpg
#   inflating: all-dogs/n02113186_8678.jpg
#   inflating: all-dogs/n02110627_13710.jpg
#   inflating: all-dogs/n02093256_4997.jpg
#   inflating: all-dogs/n02096294_568.jpg
#   inflating: all-dogs/n02113186_2433.jpg
#   inflating: all-dogs/n02093256_6158.jpg
#   inflating: all-dogs/n02111500_767.jpg
#   inflating: all-dogs/n02112350_7253.jpg
#   inflating: all-dogs/n02086646_1993.jpg
#   inflating: all-dogs/n02113799_4143.jpg
#   inflating: all-dogs/n02107908_2272.jpg
#   inflating: all-dogs/n02101556_6433.jpg
#   inflating: all-dogs/n02105641_1505.jpg
#   inflating: all-dogs/n02094114_787.jpg
#   inflating: all-dogs/n02088094_8465.jpg
#   inflating: all-dogs/n02112350_9518.jpg
#   inflating: all-dogs/n02097209_991.jpg
#   inflating: all-dogs/n02093647_665.jpg
#   inflating: all-dogs/n02097209_2347.jpg
#   inflating: all-dogs/n02088238_658.jpg
#   inflating: all-dogs/n02104365_7546.jpg
#   inflating: all-dogs/n02097658_9300.jpg
#   inflating: all-dogs/n02104029_3491.jpg
#   inflating: all-dogs/n02086910_2671.jpg
#   inflating: all-dogs/n02099601_3494.jpg
#   inflating: all-dogs/n02092002_6780.jpg
#   inflating: all-dogs/n02111277_6410.jpg
#   inflating: all-dogs/n02091831_13486.jpg
#   inflating: all-dogs/n02089867_347.jpg
#   inflating: all-dogs/n02106030_13834.jpg
#   inflating: all-dogs/n02091032_708.jpg
#   inflating: all-dogs/n02100877_1776.jpg
#   inflating: all-dogs/n02099429_3234.jpg
#   inflating: all-dogs/n02092339_3979.jpg
#   inflating: all-dogs/n02088094_4511.jpg
#   inflating: all-dogs/n02093859_567.jpg
#   inflating: all-dogs/n02105162_5489.jpg
#   inflating: all-dogs/n02106166_1133.jpg
#   inflating: all-dogs/n02093991_3824.jpg
#   inflating: all-dogs/n02110627_10225.jpg
#   inflating: all-dogs/n02107908_4159.jpg
#   inflating: all-dogs/n02110958_13597.jpg
#   inflating: all-dogs/n02093991_3830.jpg
#   inflating: all-dogs/n02092002_2294.jpg
#   inflating: all-dogs/n02112137_528.jpg
#   inflating: all-dogs/n02085620_382.jpg
#   inflating: all-dogs/n02093428_2199.jpg
#   inflating: all-dogs/n02086910_3553.jpg
#   inflating: all-dogs/n02110185_699.jpg
#   inflating: all-dogs/n02088238_664.jpg
#   inflating: all-dogs/n02088632_3667.jpg
#   inflating: all-dogs/n02105056_3445.jpg
#   inflating: all-dogs/n02107574_431.jpg
#   inflating: all-dogs/n02090379_1272.jpg
#   inflating: all-dogs/n02093859_2421.jpg
#   inflating: all-dogs/n02112137_17733.jpg
#   inflating: all-dogs/n02089078_682.jpg
#   inflating: all-dogs/n02107142_10009.jpg
#   inflating: all-dogs/n02085620_8420.jpg
#   inflating: all-dogs/n02085936_24178.jpg
#   inflating: all-dogs/n02101388_758.jpg
#   inflating: all-dogs/n02090622_7232.jpg
#   inflating: all-dogs/n02107908_1974.jpg
#   inflating: all-dogs/n02091635_2120.jpg
#   inflating: all-dogs/n02110806_2630.jpg
#   inflating: all-dogs/n02085782_230.jpg
#   inflating: all-dogs/n02102040_5604.jpg
#   inflating: all-dogs/n02088466_7670.jpg
#   inflating: all-dogs/n02112018_4813.jpg
#   inflating: all-dogs/n02108089_4002.jpg
#   inflating: all-dogs/n02094258_72.jpg
#   inflating: all-dogs/n02088632_87.jpg
#   inflating: all-dogs/n02087394_7467.jpg
#   inflating: all-dogs/n02102973_158.jpg
#   inflating: all-dogs/n02111500_31.jpg
#   inflating: all-dogs/n02101388_2324.jpg
#   inflating: all-dogs/n02105855_15820.jpg
#   inflating: all-dogs/n02093991_3603.jpg
#   inflating: all-dogs/n02095314_227.jpg
#   inflating: all-dogs/n02089867_1412.jpg
#   inflating: all-dogs/n02093428_6314.jpg
#   inflating: all-dogs/n02098105_2399.jpg
#   inflating: all-dogs/n02089078_1867.jpg
#   inflating: all-dogs/n02091831_764.jpg
#   inflating: all-dogs/n02105162_5462.jpg
#   inflating: all-dogs/n02115913_1067.jpg
#   inflating: all-dogs/n02099267_3272.jpg
#   inflating: all-dogs/n02107312_4997.jpg
#   inflating: all-dogs/n02107312_3020.jpg
#   inflating: all-dogs/n02088632_864.jpg
#   inflating: all-dogs/n02102973_1725.jpg
#   inflating: all-dogs/n02092002_5504.jpg
#   inflating: all-dogs/n02091831_7665.jpg
#   inflating: all-dogs/n02088364_15082.jpg
#   inflating: all-dogs/n02113712_4170.jpg
#   inflating: all-dogs/n02116738_500.jpg
#   inflating: all-dogs/n02111277_1394.jpg
#   inflating: all-dogs/n02110185_5624.jpg
#   inflating: all-dogs/n02109525_2035.jpg
#   inflating: all-dogs/n02094258_3435.jpg
#   inflating: all-dogs/n02105162_6625.jpg
#   inflating: all-dogs/n02091831_7895.jpg
#   inflating: all-dogs/n02108422_1017.jpg
#   inflating: all-dogs/n02086646_421.jpg
#   inflating: all-dogs/n02095570_5880.jpg
#   inflating: all-dogs/n02109525_13580.jpg
#   inflating: all-dogs/n02113023_856.jpg
#   inflating: all-dogs/n02099849_1265.jpg
#   inflating: all-dogs/n02110958_14549.jpg
#   inflating: all-dogs/n02099429_738.jpg
#   inflating: all-dogs/n02111500_6338.jpg
#   inflating: all-dogs/n02109047_5910.jpg
#   inflating: all-dogs/n02104029_4473.jpg
#   inflating: all-dogs/n02092339_5313.jpg
#   inflating: all-dogs/n02107574_380.jpg
#   inflating: all-dogs/n02116738_8653.jpg
#   inflating: all-dogs/n02102177_3658.jpg
#   inflating: all-dogs/n02093428_5635.jpg
#   inflating: all-dogs/n02116738_1105.jpg
#   inflating: all-dogs/n02091134_16109.jpg
#   inflating: all-dogs/n02096437_2900.jpg
#   inflating: all-dogs/n02091134_7567.jpg
#   inflating: all-dogs/n02092002_2257.jpg
#   inflating: all-dogs/n02112137_16388.jpg
#   inflating: all-dogs/n02106550_1889.jpg
#   inflating: all-dogs/n02111500_3254.jpg
#   inflating: all-dogs/n02093428_16682.jpg
#   inflating: all-dogs/n02087394_9462.jpg
#   inflating: all-dogs/n02089973_99.jpg
#   inflating: all-dogs/n02085936_4490.jpg
#   inflating: all-dogs/n02091635_1367.jpg
#   inflating: all-dogs/n02105855_12801.jpg
#   inflating: all-dogs/n02089078_641.jpg
#   inflating: all-dogs/n02108915_1119.jpg
#   inflating: all-dogs/n02099267_979.jpg
#   inflating: all-dogs/n02106662_16149.jpg
#   inflating: all-dogs/n02091032_907.jpg
#   inflating: all-dogs/n02105056_2798.jpg
#   inflating: all-dogs/n02092002_3968.jpg
#   inflating: all-dogs/n02108551_340.jpg
#   inflating: all-dogs/n02100877_151.jpg
#   inflating: all-dogs/n02096051_7132.jpg
#   inflating: all-dogs/n02091134_18905.jpg
#   inflating: all-dogs/n02113799_6634.jpg
#   inflating: all-dogs/n02098286_5672.jpg
#   inflating: all-dogs/n02088094_7636.jpg
#   inflating: all-dogs/n02113978_1983.jpg
#   inflating: all-dogs/n02089973_270.jpg
#   inflating: all-dogs/n02111500_5962.jpg
#   inflating: all-dogs/n02090379_1448.jpg
#   inflating: all-dogs/n02107683_4043.jpg
#   inflating: all-dogs/n02089973_3604.jpg
#   inflating: all-dogs/n02107312_1794.jpg
#   inflating: all-dogs/n02093256_1757.jpg
#   inflating: all-dogs/n02109961_8698.jpg
#   inflating: all-dogs/n02112706_1379.jpg
#   inflating: all-dogs/n02109525_16215.jpg
#   inflating: all-dogs/n02111889_15299.jpg
#   inflating: all-dogs/n02091467_4427.jpg
#   inflating: all-dogs/n02088364_13236.jpg
#   inflating: all-dogs/n02115913_90.jpg
#   inflating: all-dogs/n02099601_100.jpg
#   inflating: all-dogs/n02105855_11529.jpg
#   inflating: all-dogs/n02112706_237.jpg
#   inflating: all-dogs/n02090622_1086.jpg
#   inflating: all-dogs/n02091244_596.jpg
#   inflating: all-dogs/n02097209_2555.jpg
#   inflating: all-dogs/n02090721_3527.jpg
#   inflating: all-dogs/n02113023_4080.jpg
#   inflating: all-dogs/n02113799_7258.jpg
#   inflating: all-dogs/n02115641_9348.jpg
#   inflating: all-dogs/n02108422_1836.jpg
#   inflating: all-dogs/n02088632_3049.jpg
#   inflating: all-dogs/n02112706_223.jpg
#   inflating: all-dogs/n02095314_2904.jpg
#   inflating: all-dogs/n02096437_929.jpg
#   inflating: all-dogs/n02093754_5639.jpg
#   inflating: all-dogs/n02093256_7454.jpg
#   inflating: all-dogs/n02093256_6992.jpg
#   inflating: all-dogs/n02108551_2948.jpg
#   inflating: all-dogs/n02107574_579.jpg
#   inflating: all-dogs/n02091134_10395.jpg
#   inflating: all-dogs/n02104365_8701.jpg
#   inflating: all-dogs/n02085936_8447.jpg
#   inflating: all-dogs/n02097658_4778.jpg
#   inflating: all-dogs/n02109047_25719.jpg
#   inflating: all-dogs/n02110958_13391.jpg
#   inflating: all-dogs/n02093428_3481.jpg
#   inflating: all-dogs/n02101006_2501.jpg
#   inflating: all-dogs/n02107574_2579.jpg
#   inflating: all-dogs/n02099849_2803.jpg
#   inflating: all-dogs/n02093647_2687.jpg
#   inflating: all-dogs/n02090379_3263.jpg
#   inflating: all-dogs/n02113978_2508.jpg
#   inflating: all-dogs/n02086646_2478.jpg
#   inflating: all-dogs/n02097474_7140.jpg
#   inflating: all-dogs/n02086646_3766.jpg
#   inflating: all-dogs/n02100583_1475.jpg
#   inflating: all-dogs/n02096177_2982.jpg
#   inflating: all-dogs/n02097474_1531.jpg
#   inflating: all-dogs/n02093859_2227.jpg
#   inflating: all-dogs/n02112706_37.jpg
#   inflating: all-dogs/n02097298_9651.jpg
#   inflating: all-dogs/n02089867_1599.jpg
#   inflating: all-dogs/n02106030_16186.jpg
#   inflating: all-dogs/n02093859_2233.jpg
#   inflating: all-dogs/n02112137_11550.jpg
#   inflating: all-dogs/n02105505_3781.jpg
#   inflating: all-dogs/n02111129_4435.jpg

# %% [markdown]
# ### Build Generator and GAN
#
# We will purposely give our Generator a bottleneck in its memory. Using poor memory forces the Generator to learn a generalization of images and not memorize the images exactly.

# %%
# BUILD GENERATOR NETWORK
WrondMemory = True

if WrongMemory:
    seed = Input((10000,))
    x = Dense(2048, activation='elu')(seed)
    x = Reshape((8,8,32))(x)
    x = Conv2D(128, (3, 3), activation='elu', padding='same')(x)
    x = UpSampling2D((2, 2))(x)
    x = Conv2D(64, (3, 3), activation='elu', padding='same')(x)
    x = UpSampling2D((2, 2))(x)
    x = Conv2D(32, (3, 3), activation='elu', padding='same')(x)
    x = UpSampling2D((2, 2))(x)
    x = Conv2D(3, (3, 3), activation='linear', padding='same')(x)
    generated = Flatten()(x)
else:
    seed = Input((10000,))
    generated = Dense(12288, activation='linear')(seed)

# COMPILE
generator = Model(seed, [generated,Reshape((10000,))(seed)])

# DISPLAY ARCHITECTURE
generator.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 # BUILD GENERATOR NETWORK
#       2 WrondMemory = True
# ----> 4 if WrongMemory:
#       5     seed = Input((10000,))
#       6     x = Dense(2048, activation='elu')(seed)
#
# NameError: name 'WrongMemory' is not defined

# %% [markdown]
# ## Build Discriminator

# %%
Build Discriminator

# %% [markdown]
# ## Build Discriminator

# %%
from keras.models import Model
from keras.layers import Input, Dense, Conv2D, Reshape, Flatten, concatenate, UpSampling2D
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler
from keras.optimizers import SGD, Adam
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
# BUILD DISCRIMINATIVE NETWORK
dog = Input((12288,))
dogName = Input((10000,))
x = Dense(12288, activation='sigmoid')(dogName) 
x = Reshape((2,12288,1))(concatenate([dog,x]))
x = Conv2D(1,(2,1),use_bias=False,name='conv')(x)
discriminated = Flatten()(x)

# COMPILE
discriminator = Model([dog,dogName], discriminated)
discriminator.get_layer('conv').trainable = False
discriminator.get_layer('conv').set_weights([np.array([[[[-1.0 ]]],[[[1.0]]]])])
discriminator.compile(optimizer='adam', loss='binary_crossentropy')

# DISPLAY ARCHITECTURE
discriminator.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 10000)]      0           []
#
#  input_3 (InputLayer)           [(None, 12288)]      0           []
#
#  dense_1 (Dense)                (None, 12288)        122892288   ['input_4[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 24576)        0           ['input_3[0][0]',
#                                                                   'dense_1[0][0]']
#
#  reshape_1 (Reshape)            (None, 2, 12288, 1)  0           ['concatenate_1[0][0]']
#
#  conv (Conv2D)                  (None, 1, 12288, 1)  2           ['reshape_1[0][0]']
#
#  flatten_1 (Flatten)            (None, 12288)        0           ['conv[0][0]']
#
# ==================================================================================================
# Total params: 122,892,290
# Trainable params: 122,892,288
# Non-trainable params: 2
# __________________________________________________________________________________________________

# %% [markdown]
# ## Train Discriminator

# %%
# TRAINING DATA
train_y = (imagesIn[:10000,:,:,:]/255.).reshape((-1,12288))
train_X = np.zeros((10000,10000))
for i in range(10000): train_X[i,i] = 1
zeros = np.zeros((10000,12288))

# TRAIN NETWORK
lr = 0.5
for k in range(5):
    annealer = LearningRateScheduler(lambda x: lr)
    h = discriminator.fit([zeros,train_X], train_y, epochs = 10, batch_size=256, callbacks=[annealer], verbose=0)
    print('Epoch',(k+1)*10,'/30 - loss =',h.history['loss'][-1] )
    if h.history['loss'][-1]<0.533: lr = 0.1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # TRAINING DATA
# ----> 2 train_y = (imagesIn[:10000,:,:,:]/255.).reshape((-1,12288))
#       3 train_X = np.zeros((10000,10000))
#       4 for i in range(10000): train_X[i,i] = 1
#
# NameError: name 'imagesIn' is not defined

# %% [markdown]
# ## Delete Training Images

# %%
del train_X, train_y, imagesIn
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 del train_X, train_y, imagesIn
#
# NameError: name 'train_X' is not defined

# %%
print('Discriminator Recalls from Memory Dogs')    
for k in range(5):
    plt.figure(figsize=(15,3))
    for j in range(5):
        xx = np.zeros((10000))
        xx[np.random.randint(10000)] = 1
        plt.subplot(1,5,j+1)
        img = discriminator.predict([zeros[0,:].reshape((-1,12288)),xx.reshape((-1,10000))]).reshape((-1,64,64,3))
        img = Image.fromarray( (255*img).astype('uint8').reshape((64,64,3)))
        plt.axis('off')
        plt.imshow(img)
    plt.show()
# Out:
# Discriminator Recalls from Memory Dogs
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 8
#       6 xx[np.random.randint(10000)] = 1
#       7 plt.subplot(1,5,j+1)
# ----> 8 img = discriminator.predict([zeros[0,:].reshape((-1,12288)),xx.reshape((-1,10000))]).reshape((-1,64,64,3))
#       9 img = Image.fromarray( (255*img).astype('uint8').reshape((64,64,3)))
#      10 plt.axis('off')
#
# NameError: name 'zeros' is not defined

# %% [markdown]
# ### Submit to Kaggle
#
# In this kernel we learned how to make an experimental GAN. Currently it scores around LB 100. We must be careful as we try to improve its score. If we give this GAN excellent memory and request a mixture of 99.9% one image and 0.1% another, then it can score LB 7 but then it is returning "altered versions" of images and violates the rules here

# %%
# SAVE TO ZIP FILE NAMED IMAGES.ZIP
z = zipfile.PyZipFile('images.zip', mode='w')
d = DogGenerator()
for k in range(10000):
    img = d.getDog(np.random.normal(0,1,100))
    f = str(k)+'.png'
    img.save(f,'PNG'); z.write(f); os.remove(f)
    #if k % 1000==0: print(k)
z.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 # SAVE TO ZIP FILE NAMED IMAGES.ZIP
#       2 z = zipfile.PyZipFile('images.zip', mode='w')
# ----> 3 d = DogGenerator()
#       4 for k in range(10000):
#       5     img = d.getDog(np.random.normal(0,1,100))
#
# NameError: name 'DogGenerator' is not defined

# %%
idxIn = 0; namesIn = []
imagesIn = np.zeros((25000,64,64,3))

# CROP WITH BOUNDING BOXES TO GET DOGS ONLY
if DogsOnly:
    for breed in breeds:
        for dog in os.listdir(ROOT+'annotation/Annotation/'+breed):
            try: img = Image.open(ROOT+'all-dogs/'+dog+'.jpg') 
            except: continue           
            tree = ET.parse(ROOT+'annotation/Annotation/'+breed+'/'+dog)
            root = tree.getroot()
            objects = root.findall('object')
            for o in objects:
                bndbox = o.find('bndbox') 
                xmin = int(bndbox.find('xmin').text)
                ymin = int(bndbox.find('ymin').text)
                xmax = int(bndbox.find('xmax').text)
                ymax = int(bndbox.find('ymax').text)
                w = np.min((xmax - xmin, ymax - ymin))
                img2 = img.crop((xmin, ymin, xmin+w, ymin+w))
                img2 = img2.resize((64,64), Image.ANTIALIAS)
                imagesIn[idxIn,:,:,:] = np.asarray(img2)
                #if idxIn%1000==0: print(idxIn)
                namesIn.append(breed)
                idxIn += 1
                
# RANDOMLY CROP FULL IMAGES
else:
    x = np.random.choice(np.arange(20000),10000)
    for k in range(len(x)):
        img = Image.open(ROOT + 'all-dogs/' + IMAGES[x[k]])
        w = img.size[0]; h = img.size[1];
        if (k%2==0)|(k%3==0):
            w2 = 100; h2 = int(h/(w/100))
            a = 18; b = 0          
        else:
            a=0; b=0
            if w<h:
                w2 = 64; h2 = int((64/w)*h)
                b = (h2-64)//2
            else:
                h2 = 64; w2 = int((64/h)*w)
                a = (w2-64)//2
        img = img.resize((w2,h2), Image.ANTIALIAS)
        img = img.crop((0+a, 0+b, 64+a, 64+b))  
        imagesIn[idxIn,:,:,:] = np.asarray(img)
        namesIn.append(IMAGES[x[k]])
        #if idxIn%1000==0: print(idxIn)
        idxIn += 1
    
# DISPLAY CROPPED IMAGES
x = np.random.randint(0,idxIn,25)
for k in range(5):
    plt.figure(figsize=(15,3))
    for j in range(5):
        plt.subplot(1,5,j+1)
        img = Image.fromarray( imagesIn[x[k*5+j],:,:,:].astype('uint8') )
        plt.axis('off')
        if not DogsOnly: plt.title(namesIn[x[k*5+j]],fontsize=11)
        else: plt.title(namesIn[x[k*5+j]].split('-')[1],fontsize=11)
        plt.imshow(img)
    plt.show()
# Out:
# /tmp/ipykernel_32/3111013458.py:44: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img = img.resize((w2,h2), Image.ANTIALIAS)
